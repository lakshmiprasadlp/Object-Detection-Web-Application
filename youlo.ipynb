# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')  # You can choose other pre-trained weights like 'yolov8s.pt', 'yolov8m.pt', etc.

# Train the model on your custom dataset
model.train(data='/content/drive/MyDrive/07 yolo/data/data.yaml', epochs=30, imgsz=640, batch=16)

# Save the model
model.save('/content/drive/MyDrive/07 yolo/trained_model.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 114MB/s]
# Ultralytics YOLOv8.2.71 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

url = "https://in.images.search.yahoo.com/images/view;_ylt=AwrKAIR8zatmfnYpatu9HAx.;_ylu=c2VjA3NyBHNsawNpbWcEb2lkAzBiZDEzOWU5YzUyMzJiMjViOTdjMDNhNDE4ODFiMWYzBGdwb3MDMwRpdANiaW5n?back=https%3A%2F%2Fin.images.search.yahoo.com%2Fsearch%2Fimages%3Fp%3Dhelmet%2Bimages%26type%3DE210IN826G0%26fr%3Dmcafee%26fr2%3Dpiv-web%26tab%3Dorganic%26ri%3D3&w=3220&h=2400&imgurl=www.thetradeshop.co.uk%2Fimages%2Fpictures%2Fnew-products-2%2Fquartz-i-safety-helmet-yellow.jpg&rurl=https%3A%2F%2Fwww.thetradeshop.co.uk%2Fproducts%2Fpersonal-protective-equipment%2Fhead-protection%2Fvenitex-quartz-i-safety-helmet-product.html&size=2027.2KB&p=helmet+images&oid=0bd139e9c5232b25b97c03a41881b1f3&fr2=piv-web&fr=mcafee&tt=Venitex+Quartz+I+Safety+Helmet+-+Available+In+Blue%2C+Yellow+and+White&b=0&ni=21&no=3&ts=&tab=organic&sigr=x.HY2wCk6Btn&sigb=.1cQ6LqKFj00&sigi=fR89b.2sClCY&sigt=SnvYkJ3TsIAl&.crumb=FSZATYxbI50&fr=mcafee&fr2=piv-web&type=E210IN826G0"

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Download the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Perform object detection
results = model(img)

# Display the results using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(results[0].plot())
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-5-f93adb962aa5> in <cell line: 12>()
#      10 # Download the image from the URL
#      11 response = requests.get(url)
# ---> 12 img = Image.open(BytesIO(response.content))
#      13
#      14 # Perform object detection
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3281         warnings.warn(message)
#    3282     msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3283     raise UnidentifiedImageError(msg)
#    3284
#    3285
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x7d272597e750>

# %%
from ultralytics import YOLO
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# URL of the image
url = "https://www.thetradeshop.co.uk/images/pictures/new-products-2/quartz-i-safety-helmet-yellow.jpg"

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Download the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Perform object detection
results = model(img)

# Display the results using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(results[0].plot(show=False))
plt.axis('off')
plt.show()
# Out:
# 0: 480x640 (no detections), 144.1ms
# Speed: 4.0ms preprocess, 144.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)

# %%
from ultralytics import YOLO
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# Path to your custom trained model
custom_model_path = '/content/drive/MyDrive/07 yolo/trained_model.pt'

# Load your custom YOLO model
model = YOLO(custom_model_path)

# URL of the image
url = "https://cdn6.dissolve.com/p/D929_20_730/D929_20_730_1200.jpg"

# Download the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Perform object detection
results = model(img)

# Display the results using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(results[0].plot(show=False))
plt.axis('off')
plt.show()
# Out:
# 0: 448x640 4 Helmets, 1 Goggles, 4 Jackets, 1 Gloves, 101.5ms
# Speed: 2.8ms preprocess, 101.5ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
